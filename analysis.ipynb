# %% [markdown]
# # NYC Airbnb Data Analysis
#
# This project analyzes NYC Airbnb listings to identify pricing trends and key factors affecting listing prices.
#
# **Tools used:** Python, Pandas, Matplotlib
